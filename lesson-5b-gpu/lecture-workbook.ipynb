# %% [markdown]
# # Lesson 5b: GPU programming in Python (workbook)

# %% [markdown]
# There are no interactive questions in this session, so there's nothing to run in this notebook.
